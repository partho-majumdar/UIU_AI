# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.mstats import winsorize
import pickle

# %%
df = pd.read_csv("Train.csv")
df.shape
# Out:
# (31647, 18)

# %%
df.head(10)
# Out:
#          id  customer_age     job_type  marital  education default  balance  \
# 0  id_43823          28.0   management   single   tertiary      no    285.0
# 1  id_32289          34.0  blue-collar  married  secondary      no    934.0
# 2  id_10523          46.0   technician  married  secondary      no    656.0
# 3  id_43951          34.0     services   single  secondary      no      2.0
# 4  id_40992          41.0  blue-collar  married    primary      no   1352.0
# 5  id_12681          65.0      retired  married    primary      no   2880.0
# 6  id_41178          57.0  blue-collar  married    primary      no    495.0
# 7  id_35102          37.0   management  married   tertiary      no    650.0
# 8  id_34750          29.0   technician  married  secondary      no    265.0
# 9   id_1406          50.0  blue-collar  married  secondary      no    407.0
#
#   housing_loan personal_loan communication_type  day_of_month month  \
# 0          yes            no            unknown            26   jun
# 1           no           yes           cellular            18   nov
# 2           no            no           cellular             5   feb
# 3          yes            no            unknown            20   may
# 4          yes            no           cellular            13   may
# 5           no            no           cellular            23   apr
# 6           no            no           cellular            18   aug
# 7          yes           NaN            unknown            26   may
# 8          yes            no           cellular            19   aug
# 9          yes           yes           cellular             7   aug
#
#    last_contact_duration  num_contacts_in_campaign  \
# 0                  303.0                       4.0
# 1                  143.0                       2.0
# 2                  101.0                       4.0
# 3                  127.0                       3.0
# 4                   49.0                       2.0
# 5                  163.0                       1.0
# 6                  687.0                       4.0
# 7                  210.0                       1.0
# 8                  160.0                       2.0
# 9                  233.0                       2.0
#
#    days_since_prev_campaign_contact  num_contacts_prev_campaign  \
# 0                               NaN                           0
# 1                             132.0                           1
# 2                               NaN                           0
# 3                               NaN                           0
# 4                               NaN                           0
# 5                               NaN                           0
# 6                               NaN                           0
# 7                               NaN                           0
# 8                               NaN                           0
# 9                               NaN                           0
#
#   prev_campaign_outcome  term_deposit_subscribed
# 0               unknown                        0
# 1                 other                        0
# 2               unknown                        0
# 3               unknown                        0
# 4               unknown                        0
# 5               unknown                        1
# 6               unknown                        1
# 7               unknown                        0
# 8               unknown                        0
# 9               unknown                        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                31647 non-null  object
#  1   customer_age                      31028 non-null  float64
#  2   job_type                          31647 non-null  object
#  3   marital                           31497 non-null  object
#  4   education                         31647 non-null  object
#  5   default                           31647 non-null  object
#  6   balance                           31248 non-null  float64
#  7   housing_loan                      31647 non-null  object
#  8   personal_loan                     31498 non-null  object
#  9   communication_type                31647 non-null  object
#  10  day_of_month                      31647 non-null  int64
#  11  month                             31647 non-null  object
#  12  last_contact_duration             31336 non-null  float64
#  13  num_contacts_in_campaign          31535 non-null  float64
#  14  days_since_prev_campaign_contact  5816 non-null   float64
#  15  num_contacts_prev_campaign        31647 non-null  int64
#  16  prev_campaign_outcome             31647 non-null  object
#  17  term_deposit_subscribed           31647 non-null  int64
# dtypes: float64(5), int64(3), object(10)
# memory usage: 4.3+ MB

# %%
df.describe().T
# Out:
#                                     count         mean          std     min  \
# customer_age                      31028.0    40.439216    10.751392    18.0
# balance                           31248.0  1368.112615  3085.342417 -8020.0
# day_of_month                      31647.0    15.818561     8.322970     1.0
# last_contact_duration             31336.0   256.184038   256.181479     0.0
# num_contacts_in_campaign          31535.0     2.776629     3.153293     1.0
# days_since_prev_campaign_contact   5816.0   224.995186   114.991828     1.0
# num_contacts_prev_campaign        31647.0     0.591620     2.499675     0.0
# term_deposit_subscribed           31647.0     0.107246     0.309430     0.0
#
#                                     25%    50%      75%       max
# customer_age                       32.0   39.0    48.00      97.0
# balance                            72.0  449.0  1413.00  102128.0
# day_of_month                        8.0   16.0    21.00      31.0
# last_contact_duration             103.0  179.0   315.25    4900.0
# num_contacts_in_campaign            1.0    2.0     3.00      63.0
# days_since_prev_campaign_contact  133.0  195.0   329.00     871.0
# num_contacts_prev_campaign          0.0    0.0     0.00     275.0
# term_deposit_subscribed             0.0    0.0     0.00       1.0

# %%
df['id'].value_counts()
# Out:
# id
# id_1723     1
# id_43823    1
# id_32289    1
# id_10523    1
# id_43951    1
#            ..
# id_38719    1
# id_44317    1
# id_1993     1
# id_16413    1
# id_13459    1
# Name: count, Length: 31647, dtype: int64

# %%
df.describe(include=['object'])
# Out:
#              id     job_type  marital  education default housing_loan  \
# count     31647        31647    31497      31647   31647        31647
# unique    31647           12        3          4       2            2
# top     id_1723  blue-collar  married  secondary      no          yes
# freq          1         6816    18945      16247   31094        17700
#
#        personal_loan communication_type  month prev_campaign_outcome
# count          31498              31647  31647                 31647
# unique             2                  3     12                     4
# top               no           cellular    may               unknown
# freq           26463              20480   9685                 25833

# %%
df.isnull().sum()
# Out:
# id                                      0
# customer_age                          619
# job_type                                0
# marital                               150
# education                               0
# default                                 0
# balance                               399
# housing_loan                            0
# personal_loan                         149
# communication_type                      0
# day_of_month                            0
# month                                   0
# last_contact_duration                 311
# num_contacts_in_campaign              112
# days_since_prev_campaign_contact    25831
# num_contacts_prev_campaign              0
# prev_campaign_outcome                   0
# term_deposit_subscribed                 0
# dtype: int64

# %%
num_cols = ['customer_age', 'balance', 'last_contact_duration', 'num_contacts_in_campaign']

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
exclude_column = 'days_since_prev_campaign_contact'

# %%
all_columns = df.columns.tolist()

# %%
columns_to_check = [col for col in all_columns if col != exclude_column]

# %%
df_cleaned = df.dropna(subset=columns_to_check)

# %%
df = df_cleaned

# %%
df.isnull().sum()
# Out:
# id                                      0
# customer_age                            0
# job_type                                0
# marital                                 0
# education                               0
# default                                 0
# balance                                 0
# housing_loan                            0
# personal_loan                           0
# communication_type                      0
# day_of_month                            0
# month                                   0
# last_contact_duration                   0
# num_contacts_in_campaign                0
# days_since_prev_campaign_contact    24453
# num_contacts_prev_campaign              0
# prev_campaign_outcome                   0
# term_deposit_subscribed                 0
# dtype: int64

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
df = df.drop_duplicates(subset=['id'])
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29948 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                29948 non-null  object
#  1   customer_age                      29948 non-null  float64
#  2   job_type                          29948 non-null  object
#  3   marital                           29948 non-null  object
#  4   education                         29948 non-null  object
#  5   default                           29948 non-null  object
#  6   balance                           29948 non-null  float64
#  7   housing_loan                      29948 non-null  object
#  8   personal_loan                     29948 non-null  object
#  9   communication_type                29948 non-null  object
#  10  day_of_month                      29948 non-null  int64
#  11  month                             29948 non-null  object
#  12  last_contact_duration             29948 non-null  float64
#  13  num_contacts_in_campaign          29948 non-null  float64
#  14  days_since_prev_campaign_contact  5495 non-null   float64
#  15  num_contacts_prev_campaign        29948 non-null  int64
#  16  prev_campaign_outcome             29948 non-null  object
#  17  term_deposit_subscribed           29948 non-null  int64
# dtypes: float64(5), int64(3), object(10)
# memory usage: 4.3+ MB

# %%
df['job_type'].value_counts()
# Out:
# job_type
# blue-collar      6439
# management       6285
# technician       4964
# admin.           3424
# services         2776
# retired          1496
# self-employed    1072
# entrepreneur      969
# unemployed        865
# housemaid         841
# student           629
# unknown           188
# Name: count, dtype: int64

# %%
df['job_type'] = df['job_type'].replace({'admin.': 'admin'})

# %%
df['education'].value_counts()
# Out:
# education
# secondary    15392
# tertiary      8793
# primary       4531
# unknown       1232
# Name: count, dtype: int64

# %%
df['days_since_prev_campaign_contact'].value_counts()
# Out:
# days_since_prev_campaign_contact
# 182.0    110
# 92.0     103
# 91.0      89
# 183.0     87
# 181.0     78
#         ...
# 871.0      1
# 21.0       1
# 508.0      1
# 413.0      1
# 399.0      1
# Name: count, Length: 504, dtype: int64

# %%
df.sample(n = 10)
# Out:
#              id  customer_age     job_type  marital  education default  \
# 23274  id_44981          40.0        admin  married    primary      no
# 5802    id_1955          32.0   unemployed  married  secondary      no
# 13837  id_17739          25.0   technician  married  secondary      no
# 21908  id_28695          34.0     services  married  secondary      no
# 21407  id_22961          49.0   management  married   tertiary      no
# 19784  id_37873          30.0  blue-collar   single  secondary      no
# 8691   id_15498          36.0   management  married   tertiary      no
# 21105   id_3082          41.0        admin  married  secondary      no
# 7031   id_26287          40.0  blue-collar   single  secondary      no
# 23811  id_22904          32.0      student   single   tertiary      no
#
#        balance housing_loan personal_loan communication_type  day_of_month  \
# 23274    393.0          yes           yes           cellular             4
# 5802      25.0          yes            no           cellular            19
# 13837      7.0          yes            no           cellular            20
# 21908    -26.0          yes           yes           cellular             7
# 21407    389.0          yes           yes           cellular            21
# 19784      0.0           no           yes           cellular            31
# 8691     711.0          yes            no           cellular            11
# 21105    765.0          yes            no           cellular             3
# 7031     492.0          yes            no           cellular            20
# 23811    919.0           no            no           cellular            18
#
#       month  last_contact_duration  num_contacts_in_campaign  \
# 23274   feb                  107.0                       1.0
# 5802    nov                  616.0                       1.0
# 13837   apr                  688.0                       1.0
# 21908   jul                  155.0                       4.0
# 21407   jul                  408.0                       2.0
# 19784   jul                   15.0                      21.0
# 8691    jul                  229.0                       2.0
# 21105   sep                  237.0                       1.0
# 7031    nov                  391.0                       2.0
# 23811   oct                  323.0                       2.0
#
#        days_since_prev_campaign_contact  num_contacts_prev_campaign  \
# 23274                             208.0                           2
# 5802                                NaN                           0
# 13837                               NaN                           0
# 21908                               NaN                           0
# 21407                               NaN                           0
# 19784                               NaN                           0
# 8691                                NaN                           0
# 21105                             213.0                           1
# 7031                                NaN                           0
# 23811                               NaN                           0
#
#       prev_campaign_outcome  term_deposit_subscribed
# 23274               failure                        0
# 5802                unknown                        0
# 13837               unknown                        0
# 21908               unknown                        0
# 21407               unknown                        0
# 19784               unknown                        0
# 8691                unknown                        0
# 21105               failure                        0
# 7031                unknown                        0
# 23811               unknown                        0

# %%
df['days_since_prev_campaign_contact'].value_counts()
# Out:
# days_since_prev_campaign_contact
# 182.0    110
# 92.0     103
# 91.0      89
# 183.0     87
# 181.0     78
#         ...
# 871.0      1
# 21.0       1
# 508.0      1
# 413.0      1
# 399.0      1
# Name: count, Length: 504, dtype: int64

# %%
df.dtypes
# Out:
# id                                   object
# customer_age                        float64
# job_type                             object
# marital                              object
# education                            object
# default                              object
# balance                             float64
# housing_loan                         object
# personal_loan                        object
# communication_type                   object
# day_of_month                          int64
# month                                object
# last_contact_duration               float64
# num_contacts_in_campaign            float64
# days_since_prev_campaign_contact    float64
# num_contacts_prev_campaign            int64
# prev_campaign_outcome                object
# term_deposit_subscribed               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                                      0
# customer_age                            0
# job_type                                0
# marital                                 0
# education                               0
# default                                 0
# balance                                 0
# housing_loan                            0
# personal_loan                           0
# communication_type                      0
# day_of_month                            0
# month                                   0
# last_contact_duration                   0
# num_contacts_in_campaign                0
# days_since_prev_campaign_contact    24453
# num_contacts_prev_campaign              0
# prev_campaign_outcome                   0
# term_deposit_subscribed                 0
# dtype: int64

# %%
df['was_contacted_prev'] = df['days_since_prev_campaign_contact'].notna().astype(int)
df['days_since_prev_campaign_contact'] = df['days_since_prev_campaign_contact'].fillna(0)

# %%
df.describe().T
# Out:
#                                     count         mean          std     min  \
# customer_age                      29948.0    40.439896    10.737510    18.0
# balance                           29948.0  1365.784026  3098.998810 -8020.0
# day_of_month                      29948.0    15.826366     8.315455     1.0
# last_contact_duration             29948.0   256.655269   257.092066     0.0
# num_contacts_in_campaign          29948.0     2.774342     3.142506     1.0
# days_since_prev_campaign_contact  29948.0    41.358688   100.238187     0.0
# num_contacts_prev_campaign        29948.0     0.590390     2.528340     0.0
# term_deposit_subscribed           29948.0     0.107787     0.310116     0.0
# was_contacted_prev                29948.0     0.183485     0.387070     0.0
#
#                                     25%    50%     75%       max
# customer_age                       32.0   39.0    48.0      97.0
# balance                            72.0  449.0  1410.0  102128.0
# day_of_month                        8.0   16.0    21.0      31.0
# last_contact_duration             103.0  180.0   316.0    4900.0
# num_contacts_in_campaign            1.0    2.0     3.0      63.0
# days_since_prev_campaign_contact    0.0    0.0     0.0     871.0
# num_contacts_prev_campaign          0.0    0.0     0.0     275.0
# term_deposit_subscribed             0.0    0.0     0.0       1.0
# was_contacted_prev                  0.0    0.0     0.0       1.0

# %%
df.dtypes
# Out:
# id                                   object
# customer_age                        float64
# job_type                             object
# marital                              object
# education                            object
# default                              object
# balance                             float64
# housing_loan                         object
# personal_loan                        object
# communication_type                   object
# day_of_month                          int64
# month                                object
# last_contact_duration               float64
# num_contacts_in_campaign            float64
# days_since_prev_campaign_contact    float64
# num_contacts_prev_campaign            int64
# prev_campaign_outcome                object
# term_deposit_subscribed               int64
# was_contacted_prev                    int64
# dtype: object

# %%
df['customer_age'].plot(kind='box')
plt.show()

# %%
df[df['customer_age'] > 70]['job_type'].value_counts()
# Out:
# job_type
# retired          268
# housemaid         13
# management         7
# unknown            7
# technician         3
# admin              3
# self-employed      3
# blue-collar        2
# services           1
# entrepreneur       1
# Name: count, dtype: int64

# %%
df['balance'] = winsorize(df['balance'], limits=[0.01, 0.01])
df['last_contact_duration'] = winsorize(df['last_contact_duration'], limits=[0.01, 0.01])
df['num_contacts_in_campaign'] = winsorize(df['num_contacts_in_campaign'], limits=[0.01, 0.01])
df['num_contacts_prev_campaign'] = winsorize(df['num_contacts_prev_campaign'], limits=[0.01, 0.01])
df['customer_age'] = winsorize(df['customer_age'], limits=[0.01, 0.01])

# %%
df.describe().T
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
#                                     count         mean          std    min  \
# customer_age                      29948.0    40.397322    10.512269   22.0
# balance                           29948.0  1276.647122  2252.992078 -628.0
# day_of_month                      29948.0    15.826366     8.315455    1.0
# last_contact_duration             29948.0   253.014659   234.778775    5.0
# num_contacts_in_campaign          29948.0     2.707794     2.654992    1.0
# days_since_prev_campaign_contact  29948.0    41.358688   100.238187    0.0
# num_contacts_prev_campaign        29948.0     0.527748     1.466742    0.0
# term_deposit_subscribed           29948.0     0.107787     0.310116    0.0
# was_contacted_prev                29948.0     0.183485     0.387070    0.0
#
#                                     25%    50%     75%      max
# customer_age                       32.0   39.0    48.0     71.0
# balance                            72.0  449.0  1410.0  13186.0
# day_of_month                        8.0   16.0    21.0     31.0
# last_contact_duration             103.0  180.0   316.0   1278.0
# num_contacts_in_campaign            1.0    2.0     3.0     17.0
# days_since_prev_campaign_contact    0.0    0.0     0.0    871.0
# num_contacts_prev_campaign          0.0    0.0     0.0      9.0
# term_deposit_subscribed             0.0    0.0     0.0      1.0
# was_contacted_prev                  0.0    0.0     0.0      1.0

# %%
df = df[df['last_contact_duration'] > 0]

# %%
df = df[df['num_contacts_in_campaign'] >= 0]

# %%
df = df[df['num_contacts_prev_campaign'] >= 0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29948 entries, 0 to 31646
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                29948 non-null  object
#  1   customer_age                      29948 non-null  float64
#  2   job_type                          29948 non-null  object
#  3   marital                           29948 non-null  object
#  4   education                         29948 non-null  object
#  5   default                           29948 non-null  object
#  6   balance                           29948 non-null  float64
#  7   housing_loan                      29948 non-null  object
#  8   personal_loan                     29948 non-null  object
#  9   communication_type                29948 non-null  object
#  10  day_of_month                      29948 non-null  int64
#  11  month                             29948 non-null  object
#  12  last_contact_duration             29948 non-null  float64
#  13  num_contacts_in_campaign          29948 non-null  float64
#  14  days_since_prev_campaign_contact  29948 non-null  float64
#  15  num_contacts_prev_campaign        29948 non-null  int64
#  16  prev_campaign_outcome             29948 non-null  object
#  17  term_deposit_subscribed           29948 non-null  int64
#  18  was_contacted_prev                29948 non-null  int64
# dtypes: float64(5), int64(4), object(10)
# memory usage: 4.6+ MB

# %%
num_cols = ['customer_age', 'balance', 'last_contact_duration', 'num_contacts_in_campaign']

plt.figure(figsize=(12,6))
for i, col in enumerate(num_cols):
    plt.subplot(2, 2, i+1)
    sns.boxplot(data=df, x=col)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29948 entries, 0 to 31646
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                29948 non-null  object
#  1   customer_age                      29948 non-null  float64
#  2   job_type                          29948 non-null  object
#  3   marital                           29948 non-null  object
#  4   education                         29948 non-null  object
#  5   default                           29948 non-null  object
#  6   balance                           29948 non-null  float64
#  7   housing_loan                      29948 non-null  object
#  8   personal_loan                     29948 non-null  object
#  9   communication_type                29948 non-null  object
#  10  day_of_month                      29948 non-null  int64
#  11  month                             29948 non-null  object
#  12  last_contact_duration             29948 non-null  float64
#  13  num_contacts_in_campaign          29948 non-null  float64
#  14  days_since_prev_campaign_contact  29948 non-null  float64
#  15  num_contacts_prev_campaign        29948 non-null  int64
#  16  prev_campaign_outcome             29948 non-null  object
#  17  term_deposit_subscribed           29948 non-null  int64
#  18  was_contacted_prev                29948 non-null  int64
# dtypes: float64(5), int64(4), object(10)
# memory usage: 4.6+ MB

# %%
df
# Out:
#              id  customer_age     job_type  marital  education default  \
# 0      id_43823          28.0   management   single   tertiary      no
# 1      id_32289          34.0  blue-collar  married  secondary      no
# 2      id_10523          46.0   technician  married  secondary      no
# 3      id_43951          34.0     services   single  secondary      no
# 4      id_40992          41.0  blue-collar  married    primary      no
# ...         ...           ...          ...      ...        ...     ...
# 31642  id_27290          58.0        admin  married  secondary      no
# 31643  id_20428          51.0   management  married   tertiary      no
# 31644  id_44679          41.0   unemployed  married    primary      no
# 31645   id_4841          48.0     services  married  secondary      no
# 31646   id_1723          38.0   technician   single   tertiary      no
#
#        balance housing_loan personal_loan communication_type  day_of_month  \
# 0        285.0          yes            no            unknown            26
# 1        934.0           no           yes           cellular            18
# 2        656.0           no            no           cellular             5
# 3          2.0          yes            no            unknown            20
# 4       1352.0          yes            no           cellular            13
# ...        ...          ...           ...                ...           ...
# 31642    567.0          yes            no           cellular             2
# 31643   1072.0           no            no            unknown            20
# 31644    242.0          yes            no            unknown            23
# 31645   2699.0           no            no           cellular            11
# 31646   1045.0           no            no           cellular            18
#
#       month  last_contact_duration  num_contacts_in_campaign  \
# 0       jun                  303.0                       4.0
# 1       nov                  143.0                       2.0
# 2       feb                  101.0                       4.0
# 3       may                  127.0                       3.0
# 4       may                   49.0                       2.0
# ...     ...                    ...                       ...
# 31642   feb                   99.0                       2.0
# 31643   jun                   31.0                       7.0
# 31644   may                   89.0                       2.0
# 31645   aug                  216.0                       6.0
# 31646   aug                  183.0                      10.0
#
#        days_since_prev_campaign_contact  num_contacts_prev_campaign  \
# 0                                   0.0                           0
# 1                                 132.0                           1
# 2                                   0.0                           0
# 3                                   0.0                           0
# 4                                   0.0                           0
# ...                                 ...                         ...
# 31642                             265.0                           3
# 31643                               0.0                           0
# 31644                               0.0                           0
# 31645                               0.0                           0
# 31646                               0.0                           0
#
#       prev_campaign_outcome  term_deposit_subscribed  was_contacted_prev
# 0                   unknown                        0                   0
# 1                     other                        0                   1
# 2                   unknown                        0                   0
# 3                   unknown                        0                   0
# 4                   unknown                        0                   0
# ...                     ...                      ...                 ...
# 31642                 other                        0                   1
# 31643               unknown                        0                   0
# 31644               unknown                        0                   0
# 31645               unknown                        0                   0
# 31646               unknown                        0                   0
#
# [29948 rows x 19 columns]

# %%
df['balance_per_contact'] = df['balance'] / (df['num_contacts_in_campaign'] + 1)
df['age_balance_product'] = df['customer_age'] * df['balance']
df['campaign_intensity'] = df['num_contacts_in_campaign'] * df['last_contact_duration']

# %%
df['age_group'] = pd.cut(df['customer_age'], bins=[0, 30, 45, 60, 100], labels=['young', 'middle_aged', 'senior', 'elderly'])
df['balance_category'] = pd.qcut(df['balance'], q=3, labels=['low', 'medium', 'high'])
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(

# %%
job_counts = df['job_type'].value_counts()
rare_jobs = job_counts[job_counts < 100].index
df['job_type_grouped'] = df['job_type'].where(~df['job_type'].isin(rare_jobs), 'other')
df['job_type_freq'] = df['job_type'].map(job_counts)

# %%
df['prev_campaign_success'] = ((df['was_contacted_prev'] == 1) & (df['prev_campaign_outcome'] == 'success')).astype(int)
df['high_contact'] = (df['num_contacts_in_campaign'] > df['num_contacts_in_campaign'].quantile(0.75)).astype(int)
df['recent_contact'] = (df['days_since_prev_campaign_contact'] <= 30).astype(int)
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4842: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(

# %%
df['contact_ratio'] = df['num_contacts_in_campaign'] / (df['num_contacts_prev_campaign'] + 1)

# %%
df
# Out:
#              id  customer_age     job_type  marital  education default  \
# 0      id_43823          28.0   management   single   tertiary      no
# 1      id_32289          34.0  blue-collar  married  secondary      no
# 2      id_10523          46.0   technician  married  secondary      no
# 3      id_43951          34.0     services   single  secondary      no
# 4      id_40992          41.0  blue-collar  married    primary      no
# ...         ...           ...          ...      ...        ...     ...
# 31642  id_27290          58.0        admin  married  secondary      no
# 31643  id_20428          51.0   management  married   tertiary      no
# 31644  id_44679          41.0   unemployed  married    primary      no
# 31645   id_4841          48.0     services  married  secondary      no
# 31646   id_1723          38.0   technician   single   tertiary      no
#
#        balance housing_loan personal_loan communication_type  ...  \
# 0        285.0          yes            no            unknown  ...
# 1        934.0           no           yes           cellular  ...
# 2        656.0           no            no           cellular  ...
# 3          2.0          yes            no            unknown  ...
# 4       1352.0          yes            no           cellular  ...
# ...        ...          ...           ...                ...  ...
# 31642    567.0          yes            no           cellular  ...
# 31643   1072.0           no            no            unknown  ...
# 31644    242.0          yes            no            unknown  ...
# 31645   2699.0           no            no           cellular  ...
# 31646   1045.0           no            no           cellular  ...
#
#        age_balance_product campaign_intensity    age_group  balance_category  \
# 0                   7980.0             1212.0        young            medium
# 1                  31756.0              286.0  middle_aged            medium
# 2                  30176.0              404.0       senior            medium
# 3                     68.0              381.0  middle_aged               low
# 4                  55432.0               98.0  middle_aged              high
# ...                    ...                ...          ...               ...
# 31642              32886.0              198.0       senior            medium
# 31643              54672.0              217.0       senior              high
# 31644               9922.0              178.0  middle_aged            medium
# 31645             129552.0             1296.0       senior              high
# 31646              39710.0             1830.0  middle_aged              high
#
#        job_type_grouped  job_type_freq prev_campaign_success  high_contact  \
# 0            management           6285                     0             1
# 1           blue-collar           6439                     0             0
# 2            technician           4964                     0             1
# 3              services           2776                     0             0
# 4           blue-collar           6439                     0             0
# ...                 ...            ...                   ...           ...
# 31642             admin           3424                     0             0
# 31643        management           6285                     0             1
# 31644        unemployed            865                     0             0
# 31645          services           2776                     0             1
# 31646        technician           4964                     0             1
#
#        recent_contact  contact_ratio
# 0                   1            4.0
# 1                   0            1.0
# 2                   1            4.0
# 3                   1            3.0
# 4                   1            2.0
# ...               ...            ...
# 31642               0            0.5
# 31643               1            7.0
# 31644               1            2.0
# 31645               1            6.0
# 31646               1           10.0
#
# [29948 rows x 30 columns]

# %%
df.dtypes
# Out:
# id                                    object
# customer_age                         float64
# job_type                              object
# marital                               object
# education                             object
# default                               object
# balance                              float64
# housing_loan                          object
# personal_loan                         object
# communication_type                    object
# day_of_month                           int64
# month                                 object
# last_contact_duration                float64
# num_contacts_in_campaign             float64
# days_since_prev_campaign_contact     float64
# num_contacts_prev_campaign             int64
# prev_campaign_outcome                 object
# term_deposit_subscribed                int64
# was_contacted_prev                     int64
# balance_per_contact                  float64
# age_balance_product                  float64
# campaign_intensity                   float64
# age_group                           category
# balance_category                    category
# job_type_grouped                      object
# job_type_freq                          int64
# prev_campaign_success                  int64
# high_contact                           int64
# recent_contact                         int64
# contact_ratio                        float64
# dtype: object

# %%
drop_columns = [
    'id', 'job_type', 'day_of_month', 'month',
    'age_group', 'balance_category'
]
df = df.drop(columns=drop_columns)

# %%
df.dtypes
# Out:
# customer_age                        float64
# marital                              object
# education                            object
# default                              object
# balance                             float64
# housing_loan                         object
# personal_loan                        object
# communication_type                   object
# last_contact_duration               float64
# num_contacts_in_campaign            float64
# days_since_prev_campaign_contact    float64
# num_contacts_prev_campaign            int64
# prev_campaign_outcome                object
# term_deposit_subscribed               int64
# was_contacted_prev                    int64
# balance_per_contact                 float64
# age_balance_product                 float64
# campaign_intensity                  float64
# job_type_grouped                     object
# job_type_freq                         int64
# prev_campaign_success                 int64
# high_contact                          int64
# recent_contact                        int64
# contact_ratio                       float64
# dtype: object

# %%
categorical_cols = [
    'marital', 'education', 'default', 'housing_loan',
    'personal_loan', 'communication_type', 'prev_campaign_outcome',
    'job_type_grouped'
]

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df.columns
# Out:
# Index(['customer_age', 'balance', 'last_contact_duration',
#        'num_contacts_in_campaign', 'days_since_prev_campaign_contact',
#        'num_contacts_prev_campaign', 'term_deposit_subscribed',
#        'was_contacted_prev', 'balance_per_contact', 'age_balance_product',
#        'campaign_intensity', 'job_type_freq', 'prev_campaign_success',
#        'high_contact', 'recent_contact', 'contact_ratio', 'marital_married',
#        'marital_single', 'education_secondary', 'education_tertiary',
#        'education_unknown', 'default_yes', 'housing_loan_yes',
#        'personal_loan_yes', 'communication_type_telephone',
#        'communication_type_unknown', 'prev_campaign_outcome_other',
#        'prev_campaign_outcome_success', 'prev_campaign_outcome_unknown',
#        'job_type_grouped_blue-collar', 'job_type_grouped_entrepreneur',
#        'job_type_grouped_housemaid', 'job_type_grouped_management',
#        'job_type_grouped_retired', 'job_type_grouped_self-employed',
#        'job_type_grouped_services', 'job_type_grouped_student',
#        'job_type_grouped_technician', 'job_type_grouped_unemployed',
#        'job_type_grouped_unknown'],
#       dtype='object')

# %%
important_columns = [
    'customer_age', 'balance', 'last_contact_duration', 'num_contacts_in_campaign',
    'prev_campaign_success', 'housing_loan_yes', 'personal_loan_yes', 'education_tertiary',
    'term_deposit_subscribed'
]
df = df[important_columns]
df = df.astype(float)

# %%
corr = df[important_columns].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
X = df.drop(columns=['term_deposit_subscribed']).values
y = df['term_deposit_subscribed'].values

# %%
X_std = X.std(axis=0)
X_std[X_std == 0] = 1 
X = (X - X.mean(axis=0)) / X_std

# %%
X = np.c_[np.ones(X.shape[0]), X]

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def compute_cost(X, y, weights):
    m = len(y)
    h = sigmoid(X.dot(weights))
    epsilon = 1e-5
    cost = (-1/m) * (np.dot(y, np.log(h + epsilon)) + np.dot((1 - y), np.log(1 - h + epsilon)))
    return cost

# %%
def gradient_descent(X, y, weights, lr, iterations):
    m = len(y)
    cost_history = []
    for i in range(iterations):
        h = sigmoid(X.dot(weights))
        gradient = (1/m) * np.dot(X.T, (h - y))
        weights -= lr * gradient
        cost = compute_cost(X, y, weights)
        cost_history.append(cost)
        if i % 200 == 0:
            print(f"Iteration {i}: Cost = {cost:.4f}")
    return weights, cost_history

# %%
split_index = int(0.8 * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %%
np.random.seed(42)
weights = np.zeros(X_train.shape[1])
learning_rate = 0.01
iterations = 2000

weights, cost_history = gradient_descent(X_train, y_train, weights, learning_rate, iterations)
# Out:
# Iteration 0: Cost = 0.6913
# Iteration 200: Cost = 0.4555
# Iteration 400: Cost = 0.3592
# Iteration 600: Cost = 0.3121
# Iteration 800: Cost = 0.2857
# Iteration 1000: Cost = 0.2695
# Iteration 1200: Cost = 0.2588
# Iteration 1400: Cost = 0.2513
# Iteration 1600: Cost = 0.2459
# Iteration 1800: Cost = 0.2419

# %%
def predict(X, weights, threshold=0.5):
    probabilities = sigmoid(X.dot(weights))
    return np.array([1 if p >= threshold else 0 for p in probabilities])

y_pred = predict(X_test, weights)

# %%
def evaluate_metrics(y_true, y_pred):
    tp = sum((y_true == 1) & (y_pred == 1))
    tn = sum((y_true == 0) & (y_pred == 0))
    fp = sum((y_true == 0) & (y_pred == 1))
    fn = sum((y_true == 1) & (y_pred == 0))

    accuracy = (tp + tn) / len(y_true)
    precision = tp / (tp + fp + 1e-5)
    recall = tp / (tp + fn + 1e-5)
    f1_score = 2 * (precision * recall) / (precision + recall + 1e-5)
    
    return accuracy, precision, recall, f1_score

accuracy, precision, recall, f1 = evaluate_metrics(y_test, y_pred)

# %%
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# Accuracy:  0.9093
# Precision: 0.6395
# Recall:    0.3443
# F1-Score:  0.4476

# %%
X_no_bias = df.drop(columns=['term_deposit_subscribed']).values
mean = X_no_bias.mean(axis=0)
std = X_no_bias.std(axis=0)
std[std == 0] = 1

model_data = {
    'weights': weights,
    'mean': mean,
    'std': std,
    'columns': df.drop(columns=['term_deposit_subscribed']).columns.tolist()
}

with open('logreg_model.pkl', 'wb') as f:
    pickle.dump(model_data, f)

print("Model saved successfully")
# Out:
# Model saved successfully
